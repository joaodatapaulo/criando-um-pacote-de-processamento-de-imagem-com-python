# %%
import numpy as np
from processamento_de_imagem_em_python_desafio_dio.utils import io, plot
from processamento_de_imagem_em_python_desafio_dio.processamento import combinacao, transformacao

# %%
image1 = io.read_image('C:/Users/Joao Paulo/Desktop/img/bird-8158766_640.png') # Path image.
image2 = io.read_image('C:/Users/Joao Paulo/Desktop/img/owl-9079962_640.jpg') # Path image.

# %%
plot.plot_image(image1)
plot.plot_image(image2)

# %%
result_image = combinacao.transfer_histogram(image1, image2)
# result_image = np.clip(result_image, 0, 255)
# result_image = result_image.astype(np.uint8)
plot.plot_result(image1, image2, result_image)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0..255.0].
